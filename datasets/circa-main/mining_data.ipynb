# %% [markdown]
# ## Data Analysis - Circa Dataset (ParlAI - Facebook Research)
#
# ###### **Original Dataset:** [Circa - Indirect yes/no answers in dialog](https://github.com/google-research-datasets/circa]
# ###### **Students:** Yacine MOKHTARI & Lilia IZRI

# %% [markdown]
# ## Partie 1

# %% [markdown]
# ### Lectures des données + rapide analyse

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

PATH = "./"
FILENAME = "circa-data.tsv"
# COLNAMES = ...
df_circa_raw = pd.read_csv(PATH+FILENAME, sep="\t")

# %%
df_circa_raw.describe(include="all")
# Out:
#                   id                                            context  \
# count   34268.000000                                              34268
# unique           NaN                                                 10
# top              NaN  Y has just told X that he/she is thinking of b...
# freq             NaN                                               3500
# mean    17133.500000                                                NaN
# std      9892.463849                                                NaN
# min         0.000000                                                NaN
# 25%      8566.750000                                                NaN
# 50%     17133.500000                                                NaN
# 75%     25700.250000                                                NaN
# max     34267.000000                                                NaN
#
#                question-X  canquestion-X         answer-Y  \
# count               34268          34258            34268
# unique               3345           3259            30323
# top     Do you have kids?  I have kids .  I would love to
# freq                   40            120               59
# mean                  NaN            NaN              NaN
# std                   NaN            NaN              NaN
# min                   NaN            NaN              NaN
# 25%                   NaN            NaN              NaN
# 50%                   NaN            NaN              NaN
# 75%                   NaN            NaN              NaN
# max                   NaN            NaN              NaN
#
#                  judgements goldstandard1 goldstandard2
# count                 34268         31525         33497
# unique                 3454             8             5
# top     Yes#Yes#Yes#Yes#Yes           Yes           Yes
# freq                   9120         14504         16628
# mean                    NaN           NaN           NaN
# std                     NaN           NaN           NaN
# min                     NaN           NaN           NaN
# 25%                     NaN           NaN           NaN
# 50%                     NaN           NaN           NaN
# 75%                     NaN           NaN           NaN
# max                     NaN           NaN           NaN

# %%
df_circa_raw.head(10)
# Out:
#    id                                            context  \
# 0   0  Y has just travelled from a different city to ...
# 1   1        X wants to know about Y's food preferences.
# 2   2  Y has just told X that he/she is thinking of b...
# 3   3  X wants to know what activities Y likes to do ...
# 4   4  X and Y are childhood neighbours who unexpecte...
# 5   5  X wants to know what sorts of books Y likes to...
# 6   6        X wants to know about Y's food preferences.
# 7   7  Y has just travelled from a different city to ...
# 8   8  X wants to know what sorts of books Y likes to...
# 9   9        X wants to know about Y's food preferences.
#
#                                           question-X  \
# 0                                  Are you employed?
# 1                      Are you a fan of Korean food?
# 2           Are you bringing any pets into the flat?
# 3  Would you like to get some fresh air in your f...
# 4   Is your family still living in the neighborhood?
# 5               Do you like to read self-help books?
# 6                      Do you enjoy foreign cuisine?
# 7                        Is your new job going well?
# 8                         Are long books your thing?
# 9                        Have you had pizza recently
#
#                                      canquestion-X  \
# 0                                  I am employed .
# 1                      I am a fan of Korean food .
# 2               I am bringing pets into the flat .
# 3  I would like to get fresh air in my free time .
# 4        My family is living in the neighborhood .
# 5                 I like to read self-help books .
# 6                        I enjoy foreign cuisine .
# 7                       My new job is going well .
# 8                         Long books am my thing .
# 9                    I have I had pizza recently .
#
#                                  answer-Y  \
# 0            I'm a veterinary technician.
# 1                       I wouldn't say so
# 2                   I do not own any pets
# 3  I am desperate to get out of the city.
# 4           My parents are snowbirds now.
# 5                   I'm not a fan of them
# 6                   I like many cuisines.
# 7                       I love what I do.
# 8   I rarely read any other type of book.
# 9     My husband ordered some last night.
#
#                                           judgements  \
# 0                                Yes#Yes#Yes#Yes#Yes
# 1  Probably no#No#No#No#Probably yes / sometimes yes
# 2                                     No#No#No#No#No
# 3  Yes#Yes, subject to some conditions#Probably y...
# 4  No#In the middle, neither yes nor no#Probably ...
# 5                                     No#No#No#No#No
# 6  Yes#Yes#Yes#Probably yes / sometimes yes#Proba...
# 7       Yes#Yes#Yes#Probably yes / sometimes yes#Yes
# 8                                Yes#Yes#Yes#Yes#Yes
# 9       Yes#Probably yes / sometimes yes#Yes#Yes#Yes
#
#                        goldstandard1                      goldstandard2
# 0                                Yes                                Yes
# 1                                 No                                 No
# 2                                 No                                 No
# 3                                Yes                                Yes
# 4  In the middle, neither yes nor no  In the middle, neither yes nor no
# 5                                 No                                 No
# 6                                Yes                                Yes
# 7                                Yes                                Yes
# 8                                Yes                                Yes
# 9                                Yes                                Yes

# %%
df_circa_raw = df_circa_raw[["question-X", "canquestion-X", "answer-Y"]]
df_circa_raw.isna().sum()
# Out:
# question-X        0
# canquestion-X    10
# answer-Y          0
# dtype: int64

# %%
df_circa_raw[df_circa_raw.isna()["canquestion-X"].values]
# Out:
#                                               question-X canquestion-X  \
# 820    While you're in town do you want to go see a g...           NaN
# 2378   While you're in town do you want to go see a g...           NaN
# 7589   While you're in town do you want to go see a g...           NaN
# 8451   While you're in town do you want to go see a g...           NaN
# 10857  While you're in town do you want to go see a g...           NaN
# 16986  While you're in town do you want to go see a g...           NaN
# 22367  While you're in town do you want to go see a g...           NaN
# 32415  While you're in town do you want to go see a g...           NaN
# 32948  While you're in town do you want to go see a g...           NaN
# 33455  While you're in town do you want to go see a g...           NaN
#
#                                                 answer-Y
# 820                   I have tickets to Saturday's game.
# 2378   I wouldn't be a red-blooded American if I didn't.
# 7589                                   | would love that
# 8451                     I'd rather go dancing with you.
# 10857                    I'd rather see a baseball game.
# 16986                       If we can get cheap tickets.
# 22367                          Depends on who's playing.
# 32415                            If you can get tickets.
# 32948                          Football is a dumb sport.
# 33455                        I prefer to watch baseball.

# %% [markdown]
# **Observations**
# + Les réponses n'ont pas l'air très intéressantes, donc je préfère simplement enlever ces lignes là !

# %%
df = df_circa_raw[~df_circa_raw.isna()["canquestion-X"].values]
df.isna().sum()
# Out:
# question-X       0
# canquestion-X    0
# answer-Y         0
# dtype: int64

# %% [markdown]
# ### Extraction des Q&A

# %%
df["answer-Y"]
# Out:
# 0                  I'm a veterinary technician.
# 1                             I wouldn't say so
# 2                         I do not own any pets
# 3        I am desperate to get out of the city.
# 4                 My parents are snowbirds now.
#                           ...
# 34263                               I am in AA.
# 34264                 My favorite pie is pecan.
# 34265             I'd rather do something else.
# 34266            I can't dance to hip/hop music
# 34267               I will never have a family.
# Name: answer-Y, Length: 34258, dtype: object

# %%
df["question-X"]
# Out:
# 0                                        Are you employed?
# 1                            Are you a fan of Korean food?
# 2                 Are you bringing any pets into the flat?
# 3        Would you like to get some fresh air in your f...
# 4         Is your family still living in the neighborhood?
#                                ...
# 34263                                Do you like to drink?
# 34264                                     Do you like pie?
# 34265                     Want to go to a concert with me?
# 34266                           Do you like hip/hop music?
# 34267    Do you see yourself raising a family in New York?
# Name: question-X, Length: 34258, dtype: object

# %%
def extractQA(df):
    """
    PRECISIONS : 
        J'extrait uniquement les questions et réponses du style :
            - (question-X --> answer-Y)    /// extraction logique
            - (canquestion-X --> answer-Y) /// on préfère  avoir une réponse à la  version affirmative de l'input utilisateur
        On ne prend pas en compte le 'Yes/No/...' 
    """
    questions = list(df["question-X"].values) + list(df["canquestion-X"].values)
    answers = list(df["answer-Y"].values) * 2
    return questions, answers

# extraction
questions, answers = extractQA(df)
assert len(questions) == len(answers)
print("Nombre de Q&A total :", len(questions))
# Out:
# Nombre de Q&A total : 68516

# %%
df_qa = pd.DataFrame(data =  { "Question" : questions,  "Answer" : answers})
df_qa.head(5)
# Out:
#                                             Question  \
# 0                                  Are you employed?
# 1                      Are you a fan of Korean food?
# 2           Are you bringing any pets into the flat?
# 3  Would you like to get some fresh air in your f...
# 4   Is your family still living in the neighborhood?
#
#                                    Answer
# 0            I'm a veterinary technician.
# 1                       I wouldn't say so
# 2                   I do not own any pets
# 3  I am desperate to get out of the city.
# 4           My parents are snowbirds now.

# %% [markdown]
# ### Tests unitaires
# <small><i>Même si j'aurais du faire ça avant 🥲</i></small>

# %%
print("Nombre de paires (Q, A) duppliquées :", df_qa.duplicated().sum())
# Out:
# Nombre de paires (Q, A) duppliquées : 423

# %%
df_qa[df_qa.duplicated()]
# Out:
#                                      Question                      Answer
# 1133                       Do you have a dog?                 I have two.
# 2209                  Do you like to eat out?           I love to eat out
# 2547        Are you interested in trap music?   I don't know what that is
# 3020   Would you like to go the pub sometime?              I don't drink.
# 4408                         are you married?               I'm divorced.
# ...                                       ...                         ...
# 68078                        I work near by .           I work from home.
# 68097                           I have kids .          I wish I had kids.
# 68104                 I want large portions .  I'm trying to lose weight.
# 68285                     I am busy tonight .     I don't have any plans.
# 68335                  I have plans tonight .     I am free at the minute
#
# [423 rows x 2 columns]

# %% [markdown]
# + En regardant à peu près les données duppliquées, je me dis qu'il y aura vraiment beaucoup de choses à écrire à la main pour personnaliser notre chatbot ahaha 😭

# %%
# Retirer les dupliqués 
df_qa = df_qa[~df_qa.duplicated()]
print("Nombre de duppliqués :", df_qa.duplicated().sum())
print("Taille du dataset :", len(df_qa))
# Out:
# Nombre de duppliqués : 0
# Taille du dataset : 68093

# %% [markdown]
# ### Sauvegarder le jeu de données ainsi obtenu !

# %%
OUTPUT_PATH = "./output/"
OUTPUT_NAME = "circa-main_RAW_EXTRACTION_QA.tsv"

df_qa.to_csv(OUTPUT_PATH + OUTPUT_NAME, sep="\t", index=False)

# %% [markdown]
# ### Prochaine étape
# * Parcourir le dataset :
#     * Enlever les (Question,  Réponse) qui n'ont pas de sens/inutiles pour nous
#     * Edit certaine réponses si les questions sont intéressantes
# * Traduire en français (informel/amical : Tu et non en vous)

# %% [markdown]
# ## Partie 2

# %% [markdown]
# ### Filtrer suivant des "mots" innapropriés

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
# read_csv : 
PATH = "./output/"
FILENAME = "circa-main_RAW_EXTRACTION_QA.tsv"
df_qa = pd.read_csv(PATH+FILENAME, sep="\t")
df_qa.head(10)
# Out:
#                                             Question  \
# 0                                  Are you employed?
# 1                      Are you a fan of Korean food?
# 2           Are you bringing any pets into the flat?
# 3  Would you like to get some fresh air in your f...
# 4   Is your family still living in the neighborhood?
# 5               Do you like to read self-help books?
# 6                      Do you enjoy foreign cuisine?
# 7                        Is your new job going well?
# 8                         Are long books your thing?
# 9                        Have you had pizza recently
#
#                                    Answer
# 0            I'm a veterinary technician.
# 1                       I wouldn't say so
# 2                   I do not own any pets
# 3  I am desperate to get out of the city.
# 4           My parents are snowbirds now.
# 5                   I'm not a fan of them
# 6                   I like many cuisines.
# 7                       I love what I do.
# 8   I rarely read any other type of book.
# 9     My husband ordered some last night.

# %%
"UeuE".lower()
# Out:
# 'ueue'

# %%
qa_words_filter = ["god", "racism", "racist", "xenophobia", "sexism", "sexist"]
# looking for these only 
a_words_filter = ["husband", "wife", "boyfriend", "girlfriend", "daughter", "son"]

def word_detection(df, list_words,look_questions=False):
    idx_list = []
    for i in range(len(df)):
        tmp = df.iloc[i]
        for word in list_words:
            if (word in tmp["Answer"].lower()):
                idx_list.append(i)
            elif (look_questions) and (word in tmp["Question"].lower()):
                idx_list.append(i)
                
    return idx_list

l1 = word_detection(df_qa, a_words_filter)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-130f87186c4c> in <module>
#      15     return idx_list
#      16
# ---> 17 l1 = word_detection(df_qa, a_words_filter)
#
# <ipython-input-23-130f87186c4c> in word_detection(df, list_words, look_questions)
#       8         tmp = df.iloc[i]
#       9         for word in list_words:
# ---> 10             if (word in tmp["Answer"].values.lower()):
#      11                 idx_list.append(i)
#      12             elif (look_questions) and (word in tmp["Question"].values.lower()):
#
# AttributeError: 'str' object has no attribute 'values'
